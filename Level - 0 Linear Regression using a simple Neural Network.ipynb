# %% [markdown]
# # **The Basics: Training Your First Deep Learning Model**

# %% [markdown]
# ## **1) Import Libraries**

# %%
#Import libraries tensor flow and numpy as tf and np respectively. "tf" and "np" is the standard names.

# %% [markdown]
# ## **2) Set up training data**
#
# Hope you got the dataset with you. import it using pandas read_csv() function

# %%
#Import your dataset here using pandas library
#LotArea is our independent(or input, or x value) variable and SalePrice is our independednt(or output, or y value) variable

# %% [markdown]
# ## ***3) Create the model***
#
# In step 3 and 4 the code had been given to you. you are supposed to edit the parameters in the code and also memorise the code for future purposes.
#
# > ### Build a layer

# %%
#Define the number of dense (or hidden) layers in our neural network by editing the code below
layer = tf.keras.layers.Dense(units= "enter the number of dense layers we are using", input_shape=[1])

# %% [markdown]
# > ### Assemble layers into the model

# %%
#Insert our layer object into the sequential function
model = tf.keras.Sequential([  ])

# %% [markdown]
# > ## Compile the model, with loss and optimizer functions

# %%
#define our loss function and optimiser. We are using mean squared error as loss function and Adam optimiser. Please google how to import adam optimiser and put its value to 0.1

model.compile("Insert loss function here", "Insert Optimiser here")

# %% [markdown]
# ## **4) Train the model**

# %%
#Insert your dataset into the model. define the number of epoches, 
#An epoch is a term used in machine learning and indicates the number of passes of the entire training dataset the machine learning algorithm has completed
history = model.fit( "Insert your input x values here", "Input your output y values here" , epochs= "input the number of epoches", verbose=False)

#Verbose is just a variable to represent how our model shows each cycle of epoch. 
#verbose = 1, which includes both progress bar and one line per epoch. verbose = 0, means silent. verbose = 2, one line per epoch i.e. epoch no./total no. of epochs.

# %% [markdown]
# ## **5) Display training statistics**

# %%
#the history.hisory is a dictionary with keys loss, accuracy, lr. use this to plot a Loss vs Epoch Number graph. import and use matplotlib library to graph 2d plots

# %% [markdown]
# ## **6) Use the model to predict values**

# %%
#predict the price of a random input using model.predict() function

# %% [markdown]
# ##**Looking at the layer weights**
#
# Finally, let's print the internal variables of the Dense layer.
#
# We can get the weights using the function **get_weights()** inside our layer object which was defined in step 3.

# %%
#We used linear regression problem whose equation is y=mx+c. we gave y and x values to train the model. the parameters m and c are called "weights" in a neural network. 
#Print the weights m and c using the function get_weights()

# %% [markdown]
# Our function was y=mx+c.
#
# m and c are the weights that are internally calculated by our neural network
